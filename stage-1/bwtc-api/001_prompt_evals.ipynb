# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate an evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects, each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
  {
    "task": "Description of task",
  },
  ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a single regex
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
print(dataset)
# Out:
# [{'task': "Write a Python function that parses an AWS S3 bucket name from an S3 URI in the format 's3://bucket-name/key/path' and returns just the bucket name."}, {'task': "Create a JSON object that represents an AWS IAM policy allowing read-only access to all objects in an S3 bucket named 'my-data-bucket'."}, {'task': "Write a regex pattern that matches valid AWS EC2 security group IDs, which have the format 'sg-' followed by 8 or 17 hexadecimal characters."}]

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a Python function that extracts the bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri: str) -> str:\n    \"\"\"\n    Parse an AWS S3 bucket name from an S3 URI.\n    \n    Args:\n        s3_uri: S3 URI in the format 's3://bucket-name/key/path'\n        \n    Returns:\n        The bucket name (str)\n        \n    Raises:\n        ValueError: If the URI format is invalid\n    \"\"\"\n    if not s3_uri or not isinstance(s3_uri, str):\n        raise ValueError(\"S3 URI must be a non-empty string\")\n    \n    if not s3_uri.startswith('s3://'):\n        raise ValueError(\"S3 URI must start with 's3://'\")\n    \n    # Remove the 's3://' prefix\n    uri_without_prefix = s3_uri[5:]\n    \n    # Extract the bucket name (everything before the first '/')\n    bucket_name = uri_without_prefix.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return bucket_name\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Valid cases\n    print(parse_s3_bucket_name('s3://my-bucket/key/path'))\n    # Output: my-bucket\n    \n    print(parse_s3_bucket_name('s3://bucket-name/'))\n    # Output: bucket-name\n    \n    print(parse_s3_bucket_name('s3://bucket'))\n    # Output: bucket\n    \n    # Edge cases with error handling\n    try:\n        print(parse_s3_bucket_name('s3://'))\n    except ValueError as e:\n        print(f\"Error: {e}\")\n    \n    try:\n        print(parse_s3_bucket_name('http://bucket/key'))\n    except ValueError as e:\n        print(f\"Error: {e}\")\n    \n    try:\n        print(parse_s3_bucket_name(''))\n    except ValueError as e:\n        print(f\"Error: {e}\")\n```\n\n## Alternative Implementations\n\n### Using Regular Expressions (More Robust)\n\n```python\nimport re\n\ndef parse_s3_bucket_name(s3_uri: str) -> str:\n    \"\"\"Parse S3 bucket name using regex.\"\"\"\n    match = re.match(r's3://([^/]+)', s3_uri)\n    if not match:\n        raise ValueError(\"Invalid S3 URI format. Expected 's3://bucket-name/...'\")\n    return match.group(1)\n```\n\n### Using urllib.parse (Standard Library)\n\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_bucket_name(s3_uri: str) -> str:\n    \"\"\"Parse S3 bucket name using urlparse.\"\"\"\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != 's3':\n        raise ValueError(\"URI scheme must be 's3'\")\n    if not parsed.netloc:\n        raise ValueError(\"Bucket name cannot be empty\")\n    return parsed.netloc\n```\n\n## Comparison Table\n\n| Method | Pros | Cons |\n|--------|------|------|\n| **String split()** | Simple, no dependencies | Less robust for edge cases |\n| **Regex** | Flexible, powerful validation | Slightly more complex |\n| **urlparse** | Standard library, proper URI handling | Most code, but most robust |\n\n## Recommendation\n\n- **For simple cases**: Use the string split method\n- **For production code**: Use `urllib.parse.urlparse` for standards compliance\n- **For complex validation**: Use regex with additional checks\n\nAll three approaches correctly handle the standard S3 URI format `s3://bucket-name/key/path`.",
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket name from an S3 URI in the format 's3://bucket-name/key/path' and returns just the bucket name."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object representing an IAM policy for read-only access to all objects in the 'my-data-bucket' S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Policy Breakdown\n\n| Element | Purpose |\n|---------|---------|\n| **Version** | Specifies the policy language version (always \"2012-10-17\") |\n| **Statement 1** | Allows reading objects from the bucket |\n| `s3:GetObject` | Retrieve object contents |\n| `s3:GetObjectVersion` | Access specific object versions |\n| **Statement 2** | Allows listing bucket contents |\n| `s3:ListBucket` | View objects in the bucket |\n| `s3:GetBucketVersioning` | Check bucket versioning status |\n\n## Key Points\n\n- **Resource ARNs differ**: \n  - Objects use `arn:aws:s3:::my-data-bucket/*` (with `/*`)\n  - Bucket operations use `arn:aws:s3:::my-data-bucket` (without `/*`)\n- **Read-only**: No `Put`, `Delete`, or `Create` permissions included\n- **No write permissions**: Users cannot modify, delete, or upload objects\n\nThis policy can be attached to an IAM user, role, or group to grant read-only access to the specified S3 bucket.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to all objects in an S3 bucket named 'my-data-bucket'."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Security Group ID Regex Pattern\n\n```regex\n^sg-[0-9a-f]{8}$|^sg-[0-9a-f]{17}$\n```\n\nOr more concisely:\n\n```regex\n^sg-[0-9a-f]{8}(?:[0-9a-f]{9})?$\n```\n\n## Explanation\n\n**Pattern 1** (more explicit):\n- `^sg-` - Starts with literal \"sg-\"\n- `[0-9a-f]{8}` - Exactly 8 hexadecimal characters (0-9, a-f)\n- `$` - End of string\n- `|` - OR\n- `^sg-[0-9a-f]{17}$` - Starts with \"sg-\" followed by exactly 17 hexadecimal characters\n\n**Pattern 2** (more efficient):\n- `^sg-` - Starts with literal \"sg-\"\n- `[0-9a-f]{8}` - Exactly 8 hexadecimal characters\n- `(?:[0-9a-f]{9})?` - Optionally followed by 9 more hexadecimal characters (making it 17 total)\n- `$` - End of string\n\n## Examples\n\n**Valid matches:**\n- `sg-12345678` (8 hex chars)\n- `sg-0123456789abcdef0` (17 hex chars)\n- `sg-abcdef01` (8 hex chars)\n\n**Invalid matches:**\n- `sg-1234567` (too short)\n- `sg-123456789` (wrong length)\n- `SG-12345678` (uppercase, wrong format)\n- `sg-12345G78` (non-hex character)",
#     "test_case": {
#       "task": "Write a regex pattern that matches valid AWS EC2 security group IDs, which have the format 'sg-' followed by 8 or 17 hexadecimal characters."
#     },
#     "score": 10
#   }
# ]
